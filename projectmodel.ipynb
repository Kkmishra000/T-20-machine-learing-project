# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C://Users//seros//OneDrive//Desktop//T20 world cup project//info.csv')
df.head(n=5)
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %% [markdown]
# # while we are checking up with data do not have desired columns we are looking for
#
# 1. bowling_team
# 2. batting_team
# 3. city
# 4. current_score
# 5. balls_left
# 6. wickets_left
# 7. current_run_rate
# 8. last_five
#
# ## Now we will start our feature extraction from city column
# ## in order to start it we will first check for null values

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %% [markdown]
# # if we check above carefully the first word of venue column is actually representing the city Ex. Dubai In Dubai International Cricket Stadium

# %%
city = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = city

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %% [markdown]
# # we have filled city names in city column but we are aware that our data have approx 64000 columns we need to check how many balls are bowled and played

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue
# 0                0  Melbourne  Melbourne Cricket Ground
# 1                0  Melbourne  Melbourne Cricket Ground
# 2                0  Melbourne  Melbourne Cricket Ground
# 3                0  Melbourne  Melbourne Cricket Ground
# 4                0  Melbourne  Melbourne Cricket Ground

# %%
df.drop('venue',axis='columns',inplace = True)
df.drop('Unnamed: 0',axis = 'columns',inplace = True)

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts()>600].index.tolist()

# %% [markdown]
# # there are cities with very less deliveries we only consider those cities which have deliveries more than 600

# %%
df=df[df['city'].isin(eligible_cities)]

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne

# %%
df.shape
# Out:
# (50501, 7)

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %% [markdown]
# # Since we have extracted data from city column above we have used cumsum() function to extract current score

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score
# 0              0
# 1              0
# 2              1
# 3              3
# 4              3

# %%
df['ball']
# Out:
# 0         0.1
# 1         0.2
# 2         0.3
# 3         0.4
# 4         0.5
#          ...
# 63883    19.3
# 63884    19.4
# 63885    19.5
# 63886    19.6
# 63887    19.7
# Name: ball, Length: 50501, dtype: float64

# %% [markdown]
# # After current score we need to extract balls_left from data before that we'd be creating columns over (how many overs are completed ) and balls(how many balls has been bowled).

# %%
df['over'] = df['ball'].apply(lambda x: str(x).split(".")[0])
df['balls_no'] = df['ball'].apply(lambda x: str(x).split(".")[1])

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score over balls_no
# 0              0    0        1
# 1              0    0        2
# 2              1    0        3
# 3              3    0        4
# 4              3    0        5

# %% [markdown]
# # to calculate balls_bowled by simple formula balls_bowled = over * 6 + balls

# %%
df['balls_bowled']=(df['over'].astype('int')*6)+(df['balls_no'].astype('int'))

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score over balls_no  balls_bowled
# 0              0    0        1             1
# 1              0    0        2             2
# 2              1    0        3             3
# 3              3    0        4             4
# 4              3    0        5             5

# %% [markdown]
# # we are aware that there are 6*20=120 balls in a innings we are giving (wide,no balls) value of 0 by subtracting balls_bowled by 120 we will get balls_left

# %%
df['balls_left'] = 120-df['balls_bowled']

# %%
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1     0                0
# 1             2    Australia    Sri Lanka   0.2     0                0
# 2             2    Australia    Sri Lanka   0.3     1                0
# 3             2    Australia    Sri Lanka   0.4     2                0
# 4             2    Australia    Sri Lanka   0.5     0                0
# ...         ...          ...          ...   ...   ...              ...
# 63883       964    Sri Lanka    Australia  19.3     1                0
# 63884       964    Sri Lanka    Australia  19.4     0                0
# 63885       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6     2                0
# 63887       964    Sri Lanka    Australia  19.7     1                0
#
#             city  current_score over balls_no  balls_bowled  balls_left
# 0      Melbourne              0    0        1             1         119
# 1      Melbourne              0    0        2             2         118
# 2      Melbourne              1    0        3             3         117
# 3      Melbourne              3    0        4             4         116
# 4      Melbourne              3    0        5             5         115
# ...          ...            ...  ...      ...           ...         ...
# 63883    Colombo            125   19        3           117           3
# 63884    Colombo            125   19        4           118           2
# 63885    Colombo            125   19        5           119           1
# 63886    Colombo            127   19        6           120           0
# 63887    Colombo            128   19        7           121           0
#
# [50501 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0'else 1)

# %%
df['player_dismissed'] = df['player_dismissed'].astype('int')

# %%
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df['wickets_left'] = 10-df['player_dismissed']

# %% [markdown]
# # if player got out it will be 0 and we will replace names with 1 and apply cumsum() to calculate total wickets and than we will subtract it from 10 to get to wickets left

# %%
df['crr'] = df['current_score']/df['balls_bowled']

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         2    Australia    Sri Lanka   0.1     0                 0
# 1         2    Australia    Sri Lanka   0.2     0                 0
# 2         2    Australia    Sri Lanka   0.3     1                 0
# 3         2    Australia    Sri Lanka   0.4     2                 0
# 4         2    Australia    Sri Lanka   0.5     0                 0
#
#         city  current_score over balls_no  balls_bowled  balls_left  \
# 0  Melbourne              0    0        1             1         119
# 1  Melbourne              0    0        2             2         118
# 2  Melbourne              1    0        3             3         117
# 3  Melbourne              3    0        4             4         116
# 4  Melbourne              3    0        5             5         115
#
#    wickets_left       crr
# 0            10  0.000000
# 1            10  0.000000
# 2            10  0.333333
# 3            10  0.750000
# 4            10  0.600000

# %%
groups=df.groupby('match_id')

match_ids=df['match_id'].unique()
last_five=[]
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %% [markdown]
# # we will be having scores of last five overs

# %%
df['last_five'] = last_five

# %%
final_df=df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  0.333333        NaN     168
# 3                10  0.750000        NaN     168
# 4                10  0.600000        NaN     168
# ...             ...       ...        ...     ...
# 50496             2  1.068376       32.0     128
# 50497             2  1.059322       32.0     128
# 50498             1  1.050420       32.0     128
# 50499             1  1.058333       33.0     128
# 50500             1  1.057851       32.0     128
#
# [50501 rows x 9 columns]

# %% [markdown]
# # We have extracted all desired columns from data and named it final_df

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace = True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %% [markdown]
# # we have dropped all null values from final_df

# %%
final_df = final_df.sample(final_df.shape[0])

# %% [markdown]
# # To avoid any kind of bias in final_df we have shuffled the data

# %%
final_df.head()
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 29427     Sri Lanka     Australia     Pallekele             47          82
# 36592     Sri Lanka     Australia     Melbourne            135           8
# 40227  South Africa       England    Chittagong             50          84
# 26674   New Zealand     Australia  Christchurch            210           2
# 9851      Australia  South Africa  Johannesburg            104          56
#
#        wickets_left       crr  last_five  runs_x
# 29427             8  1.236842       40.0     198
# 36592             6  1.205357       45.0     161
# 40227            10  1.388889       44.0     196
# 26674             4  1.779661       65.0     214
# 9851              8  1.625000       31.0     196

# %%
from sklearn.model_selection import train_test_split
X = final_df.drop('runs_x',axis = 'columns')
Y = final_df['runs_x']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %% [markdown]
# # Since we have completed data extraction now its time start model building for that i have splitted final_df into train and test data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\seros\appdata\local\programs\python\python311\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\seros\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\seros\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(drop = 'first'),['batting_team','bowling_team','city'])
], 
 remainder='passthrough')

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler(with_mean=False)),
    ('step3',XGBRegressor(n_estimators=300,learning_rate=0.2,max_depth=12,random_state=1))

])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler(with_mean=False)),
#                 ('step3',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               earl...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=12, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=300, n_jobs=None,
#                               num_parallel_tree=None, random_state=1, ...))])

# %%
Y_pred = pipe.predict(X_test)

# %%
print(r2_score(y_test,Y_pred))
print(mean_absolute_error(y_test,Y_pred))
# Out:
# 0.9861394087268817
# 1.7001399458569946

# %%
import pickle

# %%
pickle.dump(pipe,open("pipe.pkl","wb"))

# %%
final_df
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 29427     Sri Lanka     Australia     Pallekele             47          82
# 36592     Sri Lanka     Australia     Melbourne            135           8
# 40227  South Africa       England    Chittagong             50          84
# 26674   New Zealand     Australia  Christchurch            210           2
# 9851      Australia  South Africa  Johannesburg            104          56
# ...             ...           ...           ...            ...         ...
# 23270   New Zealand     Sri Lanka       Colombo             38          84
# 48822     Australia         India    Chandigarh            154           1
# 16481  South Africa       England     Cape Town             86          48
# 11877     Australia       England   Southampton             48          75
# 34939         India     Sri Lanka     Pallekele             64          69
#
#        wickets_left       crr  last_five  runs_x
# 29427             8  1.236842       40.0     198
# 36592             6  1.205357       45.0     161
# 40227            10  1.388889       44.0     196
# 26674             4  1.779661       65.0     214
# 9851              8  1.625000       31.0     196
# ...             ...       ...        ...     ...
# 23270             8  1.055556       33.0     141
# 48822             4  1.294118       40.0     160
# 16481             7  1.194444       37.0     154
# 11877             7  1.066667       39.0     157
# 34939             9  1.254902       36.0     155
#
# [38477 rows x 9 columns]
